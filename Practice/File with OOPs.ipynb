# %%
# Day 1-2: Student class + .txt file handling
# Fill in the TODOs yourself — this is a skeleton, not the full solution.
# Run this file and test each method one by one.

class Student:
    def __init__(self, name, marks):
        self.marks=name
        self.marks=marks

    def save_to_txt(self, filename="student.txt"):
        with open(filename,'a') as file:
            file.write(f"Name:{self.name}Marks:,{self.marks}")

            

    @staticmethod
    def load_from_txt(filename="student.txt"):
        """
        Read a student back from a text file and return a Student object.
        Hint: use `with open(filename, 'r') as f:` then f.read() or f.readlines()
        You'll need to split the line back into name and marks.
        """
        # TODO
        pass

    def __str__(self):
        # TODO: return a readable string like "Name: X, Marks: Y"
        # This runs automatically when you do print(some_student)
        pass


# ---- Test your code below ----
if __name__ == "__main__":
    # 1. Create a student
    s1 = Student("Arjun", 85)

    # 2. Print it (tests __str__)
    print(s1)

    # 3. Save it to a file
    s1.save_to_txt("student.txt")

    # 4. Load it back from the file into a NEW object
    s2 = Student.load_from_txt("student.txt")

    # 5. Print the loaded one — it should match what you saved
    print(s2)

    # If s2 prints the same name/marks as s1, your save + load logic works.

# %%
def save_to_txt(filename="student.txt"):
        with open(filename,'a') as file:
            file.write("Name:")
save_to_txt()
